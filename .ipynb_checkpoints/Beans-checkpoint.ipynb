# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define directories
train_dir = "C:\\Users\\User\\Desktop\\Plant_disease_7CROPS\\Beans\\Train"
test_dir = "C:\\Users\\User\\Desktop\\Plant_disease_7CROPS\\Beans\\Test"
validation_dir = "C:\\Users\\User\\Desktop\\Plant_disease_7CROPS\\Beans\\Validation"

# %%
# Define the image size
img_size = (150, 150)
batch_size = 32

# Count the number of classes
num_classes = len(os.listdir(train_dir))

# Define the data generators
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 4482 images belonging to 3 classes.
# Found 1148 images belonging to 3 classes.
# Found 625 images belonging to 3 classes.

# %%
# MobileNet Model
base_model = MobileNet(weights='imagenet', include_top=False)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(num_classes, activation='softmax')(x)

mobilenet_model = Model(inputs=base_model.input, outputs=predictions)

for layer in base_model.layers:
    layer.trainable = False

mobilenet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

mobilenet_history = mobilenet_model.fit(
    train_generator,
    epochs=25,
    validation_data=validation_generator
)

mobilenet_evaluation = mobilenet_model.evaluate(test_generator)
print("MobileNet Test Accuracy:", mobilenet_evaluation[1])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/25
# 141/141 [==============================] - 38s 256ms/step - loss: 0.2891 - accuracy: 0.9627 - val_loss: 0.1257 - val_accuracy: 0.9495
# Epoch 2/25
# 141/141 [==============================] - 36s 254ms/step - loss: 0.0288 - accuracy: 0.9884 - val_loss: 0.0437 - val_accuracy: 0.9808
# Epoch 3/25
# 141/141 [==============================] - 36s 252ms/step - loss: 0.0169 - accuracy: 0.9926 - val_loss: 0.0340 - val_accuracy: 0.9869
# Epoch 4/25
# 141/141 [==============================] - 35s 251ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0303 - val_accuracy: 0.9869
# Epoch 5/25
# 141/141 [==============================] - 35s 247ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0328 - val_accuracy: 0.9861
# Epoch 6/25
# 141/141 [==============================] - 35s 246ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9887
# Epoch 7/25
# 141/141 [==============================] - 36s 254ms/step - loss: 6.4468e-04 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9895
# Epoch 8/25
# 141/141 [==============================] - 36s 254ms/step - loss: 4.0295e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9878
# Epoch 9/25
# 141/141 [==============================] - 35s 248ms/step - loss: 2.8594e-04 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 0.9887
# Epoch 10/25
# 141/141 [==============================] - 35s 245ms/step - loss: 2.1593e-04 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9887
# Epoch 11/25
# 141/141 [==============================] - 34s 241ms/step - loss: 1.7289e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9878
# Epoch 12/25
# 141/141 [==============================] - 35s 247ms/step - loss: 1.4084e-04 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9878
# Epoch 13/25
# 141/141 [==============================] - 34s 244ms/step - loss: 1.1506e-04 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9895
# Epoch 14/25
# 141/141 [==============================] - 34s 239ms/step - loss: 9.5447e-05 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9878
# Epoch 15/25
# 141/141 [==============================] - 34s 238ms/step - loss: 8.0970e-05 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9887
# Epoch 16/25
# 141/141 [==============================] - 36s 253ms/step - loss: 7.2687e-05 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9878
# Epoch 17/25
# 141/141 [==============================] - 36s 254ms/step - loss: 5.9226e-05 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9887
# Epoch 18/25
# 141/141 [==============================] - 35s 248ms/step - loss: 4.9605e-05 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9887
# Epoch 19/25
# 141/141 [==============================] - 35s 247ms/step - loss: 4.3985e-05 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9887
# Epoch 20/25
# 141/141 [==============================] - 35s 248ms/step - loss: 3.7926e-05 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.
ms/step - loss: 0.0097 - accuracy: 0.9962 - val_loss: 0.1195 - val_accuracy: 0.9713
# Epoch 15/25
# 141/141 [==============================] - 85s 604ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.1133 - val_accuracy: 0.9756
# Epoch 16/25
# 141/141 [==============================] - 85s 605ms/step - loss: 0.0515 - accuracy: 0.9837 - val_loss: 0.1545 - val_accuracy: 0.9521
# Epoch 17/25
# 141/141 [==============================] - 84s 596ms/step - loss: 0.0195 - accuracy: 0.9926 - val_loss: 0.1494 - val_accuracy: 0.9678
# Epoch 18/25
# 141/141 [==============================] - 84s 595ms/step - loss: 0.0189 - accuracy: 0.9915 - val_loss: 0.1026 - val_accuracy: 0.9660
# Epoch 19/25
# 141/141 [==============================] - 84s 598ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 0.1523 - val_accuracy: 0.9678
# Epoch 20/25
# 141/141 [==============================] - 86s 609ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.1694 - val_accuracy: 0.9660
# Epoch 21/25
# 141/141 [==============================] - 84s 596ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.2375 - val_accuracy: 0.9617
# Epoch 22/25
# 141/141 [==============================] - 84s 602ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.2256 - val_accuracy: 0.9634
# Epoch 23/25
# 141/141 [==============================] - 84s 595ms/step - loss: 0.0261 - accuracy: 0.9915 - val_loss: 0.1878 - val_accuracy: 0.9669
# Epoch 24/25
# 141/141 [==============================] - 84s 596ms/step - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.1430 - val_accuracy: 0.9643
# Epoch 25/25
# 141/141 [==============================] - 84s 596ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.1651 - val_accuracy: 0.9695
# 20/20 [==============================] - 3s 150ms/step - loss: 0.3571 - accuracy: 0.9264
# CNN Test Accuracy: 0.9264000058174133

# %%
# Confusion matrix for MobileNet
mobilenet_predictions = mobilenet_model.predict(test_generator)
mobilenet_pred_labels = np.argmax(mobilenet_predictions, axis=1)
mobilenet_true_labels = test_generator.classes

mobilenet_conf_matrix = confusion_matrix(mobilenet_true_labels, mobilenet_pred_labels)

# Confusion matrix for CNN from scratch
cnn_predictions = cnn_model.predict(test_generator)
cnn_pred_labels = np.argmax(cnn_predictions, axis=1)

cnn_conf_matrix = confusion_matrix(mobilenet_true_labels, cnn_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.heatmap(mobilenet_conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('MobileNet Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')

plt.subplot(1, 2, 2)
sns.heatmap(cnn_conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('CNN Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')

plt.tight_layout()
plt.show()
# Out:
# 20/20 [==============================] - 5s 196ms/step
# 20/20 [==============================] - 3s 111ms/step

# %%
# Print the summary of the CNN model
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense_2 (Dense)             (None, 512)               18940416
#
#  dense_3 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 19035203 (72.61 MB)
# Trainable params: 19035203 (72.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
